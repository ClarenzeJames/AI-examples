# %%
run starter.py
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# File ~\Desktop\courseraAI\starter.py:25
#      22 p.setRealTimeSimulation(1)
#      24 while True:
# ---> 25     for i in range(p.getNumJoints(cid)):
#      26         m = c.get_motors()[i]
#      27         p.setJointMotorControl2(cid, i, controlMode=p.VELOCITY_CONTROL,
#      28                                 targetVelocity=m.get_output(), force=5)
#
# error: Not connected to physics server.

# %%
import pybullet as p
import pybullet_data as pd
import creature

p.connect(p.GUI)
p.setPhysicsEngineParameter(enableFileCaching=0)
p.configureDebugVisualizer(p.COV_ENABLE_GUI,0)

# creating the floor
floor_shape = p.createCollisionShape(p.GEOM_PLANE)
floor =  p.createMultiBody(floor_shape,floor_shape)
p.setRealTimeSimulation(1)
p.setGravity(0,0,-10)

# %%
c = creature.Creature(gene_count=5)
xml_str = c.to_xml()
print(xml_str)
with open('test.urdf','w') as f:
    f.write(xml_str)

cid = p.loadURDF('test.urdf')
# Out:
# 1
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 2
# 2
# <genome.URDFLink object at 0x00000271A7478EC0>
# <genome.URDFLink object at 0x00000271A73CFAD0>
# <genome.URDFLink object at 0x00000271A7159AE0>
# <genome.URDFLink object at 0x00000271A73DBDF0>
# <genome.URDFLink object at 0x00000271A6F83750>
# <genome.URDFLink object at 0x00000271A74B9050>
# <genome.URDFLink object at 0x00000271A73BBF20>
# <genome.URDFLink object at 0x00000271A74E8500>
# <genome.URDFLink object at 0x00000271A74E85F0>
# <genome.URDFLink object at 0x00000271A74E86E0>
# <genome.URDFLink object at 0x00000271A74E87D0>
# <genome.URDFLink object at 0x00000271A74E88C0>
# <genome.URDFLink object at 0x00000271A74E89B0>
# <genome.URDFLink object at 0x00000271A74E8AA0>
# <genome.URDFLink object at 0x00000271A74E8B90>
# <genome.URDFLink object at 0x00000271A74E8C80>
# <genome.URDFLink object at 0x00000271A74E8D70>
# <genome.URDFLink object at 0x00000271A74E8E60>
# <genome.URDFLink object at 0x00000271A74E8F50>
# <genome.URDFLink object at 0x00000271A74E9040>
# <genome.URDFLink object at 0x00000271A74E9130>
# <genome.URDFLink object at 0x00000271A74E9220>
# <genome.URDFLink object at 0x00000271A74E9310>
# <genome.URDFLink object at 0x00000271A74E9400>
# <?xml version="1.0"?>
# <robot name="pepe">
# 	<link name="0">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.05849309551434667" radius="0.2672322969443196"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.05849309551434667" radius="0.2672322969443196"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="0.013122976984362541"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="21">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.16282648844208059" radius="0.3747523710002725"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.16282648844208059" radius="0.3747523710002725"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="0.0718395673333176"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="42">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.6178750735279873" radius="0.6859372418117727"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.6178750735279873" radius="0.6859372418117727"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="0.9133123144896862"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="63">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="1.5866702387245637"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="64">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="1.5866702387245637"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="65">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="1.5866702387245637"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="66">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="1.5866702387245637"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="47">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.6178750735279873" radius="0.6859372418117727"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.6178750735279873" radius="0.6859372418117727"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="0.9133123144896862"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="68">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="1.5866702387245637"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="69">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="1.5866702387245637"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="610">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="1.5866702387245637"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="611">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="1.5866702387245637"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="412">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.6178750735279873" radius="0.6859372418117727"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.6178750735279873" radius="0.6859372418117727"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="0.9133123144896862"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="613">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="1.5866702387245637"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="614">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="1.5866702387245637"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="615">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="1.5866702387245637"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="616">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="1.5866702387245637"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="417">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.6178750735279873" radius="0.6859372418117727"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.6178750735279873" radius="0.6859372418117727"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="0.9133123144896862"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="618">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="1.5866702387245637"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="619">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="1.5866702387245637"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="620">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="1.5866702387245637"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="621">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.866141299474304" radius="0.7636142564097401"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="1.5866702387245637"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="822">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.2584379173334501" radius="0.20173747301759215"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.2584379173334501" radius="0.20173747301759215"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="0.03304298386168493"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<link name="823">
# 		<visual>
# 			<geometry>
# 				<cylinder length="0.2584379173334501" radius="0.20173747301759215"/>
# 			</geometry>
# 		</visual>
# 		<collision>
# 			<geometry>
# 				<cylinder length="0.2584379173334501" radius="0.20173747301759215"/>
# 			</geometry>
# 		</collision>
# 		<inertial>
# 			<mass value="0.03304298386168493"/>
# 			<inertia ixx="0.03" iyy="0.03" izz="0.03" ixy="0" ixz="0" iyx="0"/>
# 		</inertial>
# 	</link>
# 	<joint name="21_to_0" type="revolute">
# 		<parent link="0"/>
# 		<child link="21"/>
# 		<axis xyz="0 1 0"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="4.737322119911407 6.124536302366743 4.782791001722313" xyz="0.6153185535048875 0.8281195361186879 0.3191120758285021"/>
# 	</joint>
# 	<joint name="42_to_21" type="revolute">
# 		<parent link="21"/>
# 		<child link="42"/>
# 		<axis xyz="1 0 0"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="0.018932065802115334 3.980159367506136 5.84698508674984" xyz="0.12969784598227296 0.27539110039487547 0.40671554970209556"/>
# 	</joint>
# 	<joint name="63_to_42" type="revolute">
# 		<parent link="42"/>
# 		<child link="63"/>
# 		<axis xyz="0 0 1"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="5.986797651657427 5.735764077859907 1.8159829719941722" xyz="0.41116557929850117 0.20966104753986026 0.7284829723228076"/>
# 	</joint>
# 	<joint name="64_to_42" type="revolute">
# 		<parent link="42"/>
# 		<child link="64"/>
# 		<axis xyz="0 0 1"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="5.986797651657427 5.735764077859907 1.8159829719941722" xyz="0.41116557929850117 0.20966104753986026 0.7284829723228076"/>
# 	</joint>
# 	<joint name="65_to_42" type="revolute">
# 		<parent link="42"/>
# 		<child link="65"/>
# 		<axis xyz="0 0 1"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="5.986797651657427 5.735764077859907 1.8159829719941722" xyz="0.41116557929850117 0.20966104753986026 0.7284829723228076"/>
# 	</joint>
# 	<joint name="66_to_42" type="revolute">
# 		<parent link="42"/>
# 		<child link="66"/>
# 		<axis xyz="0 0 1"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="5.986797651657427 5.735764077859907 1.8159829719941722" xyz="0.41116557929850117 0.20966104753986026 0.7284829723228076"/>
# 	</joint>
# 	<joint name="47_to_21" type="revolute">
# 		<parent link="21"/>
# 		<child link="47"/>
# 		<axis xyz="1 0 0"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="0.018932065802115334 3.980159367506136 5.84698508674984" xyz="0.12969784598227296 0.27539110039487547 0.40671554970209556"/>
# 	</joint>
# 	<joint name="68_to_47" type="revolute">
# 		<parent link="47"/>
# 		<child link="68"/>
# 		<axis xyz="0 0 1"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="5.986797651657427 5.735764077859907 1.8159829719941722" xyz="0.41116557929850117 0.20966104753986026 0.7284829723228076"/>
# 	</joint>
# 	<joint name="69_to_47" type="revolute">
# 		<parent link="47"/>
# 		<child link="69"/>
# 		<axis xyz="0 0 1"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="5.986797651657427 5.735764077859907 1.8159829719941722" xyz="0.41116557929850117 0.20966104753986026 0.7284829723228076"/>
# 	</joint>
# 	<joint name="610_to_47" type="revolute">
# 		<parent link="47"/>
# 		<child link="610"/>
# 		<axis xyz="0 0 1"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="5.986797651657427 5.735764077859907 1.8159829719941722" xyz="0.41116557929850117 0.20966104753986026 0.7284829723228076"/>
# 	</joint>
# 	<joint name="611_to_47" type="revolute">
# 		<parent link="47"/>
# 		<child link="611"/>
# 		<axis xyz="0 0 1"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="5.986797651657427 5.735764077859907 1.8159829719941722" xyz="0.41116557929850117 0.20966104753986026 0.7284829723228076"/>
# 	</joint>
# 	<joint name="412_to_21" type="revolute">
# 		<parent link="21"/>
# 		<child link="412"/>
# 		<axis xyz="1 0 0"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="0.018932065802115334 3.980159367506136 5.84698508674984" xyz="0.12969784598227296 0.27539110039487547 0.40671554970209556"/>
# 	</joint>
# 	<joint name="613_to_412" type="revolute">
# 		<parent link="412"/>
# 		<child link="613"/>
# 		<axis xyz="0 0 1"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="5.986797651657427 5.735764077859907 1.8159829719941722" xyz="0.41116557929850117 0.20966104753986026 0.7284829723228076"/>
# 	</joint>
# 	<joint name="614_to_412" type="revolute">
# 		<parent link="412"/>
# 		<child link="614"/>
# 		<axis xyz="0 0 1"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="5.986797651657427 5.735764077859907 1.8159829719941722" xyz="0.41116557929850117 0.20966104753986026 0.7284829723228076"/>
# 	</joint>
# 	<joint name="615_to_412" type="revolute">
# 		<parent link="412"/>
# 		<child link="615"/>
# 		<axis xyz="0 0 1"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="5.986797651657427 5.735764077859907 1.8159829719941722" xyz="0.41116557929850117 0.20966104753986026 0.7284829723228076"/>
# 	</joint>
# 	<joint name="616_to_412" type="revolute">
# 		<parent link="412"/>
# 		<child link="616"/>
# 		<axis xyz="0 0 1"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="5.986797651657427 5.735764077859907 1.8159829719941722" xyz="0.41116557929850117 0.20966104753986026 0.7284829723228076"/>
# 	</joint>
# 	<joint name="417_to_21" type="revolute">
# 		<parent link="21"/>
# 		<child link="417"/>
# 		<axis xyz="1 0 0"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="0.018932065802115334 3.980159367506136 5.84698508674984" xyz="0.12969784598227296 0.27539110039487547 0.40671554970209556"/>
# 	</joint>
# 	<joint name="618_to_417" type="revolute">
# 		<parent link="417"/>
# 		<child link="618"/>
# 		<axis xyz="0 0 1"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="5.986797651657427 5.735764077859907 1.8159829719941722" xyz="0.41116557929850117 0.20966104753986026 0.7284829723228076"/>
# 	</joint>
# 	<joint name="619_to_417" type="revolute">
# 		<parent link="417"/>
# 		<child link="619"/>
# 		<axis xyz="0 0 1"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="5.986797651657427 5.735764077859907 1.8159829719941722" xyz="0.41116557929850117 0.20966104753986026 0.7284829723228076"/>
# 	</joint>
# 	<joint name="620_to_417" type="revolute">
# 		<parent link="417"/>
# 		<child link="620"/>
# 		<axis xyz="0 0 1"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="5.986797651657427 5.735764077859907 1.8159829719941722" xyz="0.41116557929850117 0.20966104753986026 0.7284829723228076"/>
# 	</joint>
# 	<joint name="621_to_417" type="revolute">
# 		<parent link="417"/>
# 		<child link="621"/>
# 		<axis xyz="0 0 1"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="5.986797651657427 5.735764077859907 1.8159829719941722" xyz="0.41116557929850117 0.20966104753986026 0.7284829723228076"/>
# 	</joint>
# 	<joint name="822_to_0" type="revolute">
# 		<parent link="0"/>
# 		<child link="822"/>
# 		<axis xyz="0 1 0"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="2.4939088153879307 5.43482740156142 1.4288995407759828" xyz="0.7342663889755077 0.7326829410186347 0.6227828917287632"/>
# 	</joint>
# 	<joint name="823_to_0" type="revolute">
# 		<parent link="0"/>
# 		<child link="823"/>
# 		<axis xyz="0 1 0"/>
# 		<limit effort="1" lower="1" upper="0" velocity="1"/>
# 		<origin rpy="2.4939088153879307 5.43482740156142 1.4288995407759828" xyz="0.7342663889755077 0.7326829410186347 0.6227828917287632"/>
# 	</joint>
# </robot>
